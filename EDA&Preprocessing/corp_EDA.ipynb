# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 500    
pd.options.display.max_columns = 20

# %%
corp = pd.read_csv('company1.csv')

# %%
corp.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1, inplace=True)
corp
# Out:
#                  기업명 기업구분2                         기업구분  사원수2  \
# 0            (주)페이타랩  중소기업     중소기업, 스타트업, 주식회사, 병역특례..    52
# 1          (주)엠제이플렉스  중소기업     중소기업, 스타트업, 외부감사법인, 주식..   930
# 2              (주)앰진  중소기업                   중소기업, 주식회사    20
# 3            (주)도킹블록  중소기업                   중소기업, 주식회사    11
# 4         (주)헥토이노베이션  중소기업     코스닥, 중소기업, 주식회사, 병역특례 ..   140
# 5         (주)세종분석연구원  중소기업                   중소기업, 주식회사     3
# 6           (주)엑스큐어넷  중소기업                   중소기업, 주식회사    67
# 7             (주)미디움  중소기업           중소기업, 외부감사법인, 주식회사    80
# 8        (주)씨씨미디어서비스  중소기업                   중소기업, 주식회사    75
# 9        (주)한국컨텐츠인프라  중소기업           중소기업, 주식회사, 수출입 기업    27
# 10        (주)한국빌링시스템  중소기업           중소기업, 외부감사법인, 주식회사    39
# 11            (주)이타즈  중소기업                         중소기업    17
# 12      (주)더블다운인터액티브  중소기업                   중소기업, 주식회사   173
# 13    (주)데이터디자인엔지니어링  중소기업         중소기업, 외국인 투자기업, 주식회사    17
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
plt.rcParams["axes.unicode_minus"] = False
rc("font", family= "Malgun Gothic")
# %matplotlib inline

# %% [markdown]
# # EDA

# %% [markdown]
# ### 기업구분에 따른 회사 수

# %%
sns.countplot(x='기업구분2', data=corp);

# %% [markdown]
# - 중소기업의 수가 압도적으로 많다.

# %% [markdown]
# ### 기업구분에 따른 사원수

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x='사원수2', y='기업구분2', data=corp)
plt.show()

# %% [markdown]
# - 중견기업, 대기업, 기타 ==> 이상치 제거 필요
# - 중소기업은 max로 해서 가장 큰 값 두개 만 제거하자

# %%
# 별점의 분포가 어떤지 : countplot 은 데이터의 개수를 표시하는 플롯
plt.figure(figsize=(12, 8))
sns.countplot(data=corp, x='별점');

# %% [markdown]
# ### 기업구분에 따른 별점 상자그래프

# %%
plt.figure(figsize=(6,4))
# sns.boxplot(x='별점', y='기업구분2', data=corp)
sns.boxplot(x='기업구분2', y='별점', data=corp)
plt.show()

# %% [markdown]
# - 별점은 이상치 제거하면 안될것 같다.
# - 별점은 이상치가 더 중요한 데이터 값 --> 과연?

# %%
# 별점별 사원수 
plt.figure(figsize=(12, 8))
sns.barplot(x='별점', y='사원수2', data=corp);

# %%
# 입사율,퇴사율 수치만 가져와서 확인
corp['입사율(%)'] = corp['입사율'].str.split().str[0]
corp['퇴사율(%)'] = corp['퇴사율'].str.split().str[0]
corp['입사율(%)'] = corp['입사율(%)'].astype('float')
corp['퇴사율(%)'] = corp['퇴사율(%)'].astype('float')
corp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   기업명      185 non-null    object
#  1   기업구분2    185 non-null    object
#  2   기업구분     185 non-null    object
#  3   사원수2     185 non-null    int64
#  4   사원수      185 non-null    object
#  5   설립일(업력)  185 non-null    object
#  6   홈페이지     177 non-null    object
#  7   지역       185 non-null    object
#  8   별점       185 non-null    float64
#  9   입사율      185 non-null    object
#  10  퇴사율      185 non-null    object
#  11  입사율(%)   185 non-null    float64
#  12  퇴사율(%)   185 non-null    float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# ### 입사율 및 퇴사율과 별점 사이의 관계 확인

# %%
sns.pairplot(corp[['별점','입사율(%)','퇴사율(%)']])

# %% [markdown]
# ###  지역(도) 기준으로 별점 분포 확인

# %%
corp['지역(도)'] = corp['지역'].str.split().str[0]
sns.barplot(data=corp, x= '지역(도)', y="별점")
# Out:
# <AxesSubplot: xlabel='지역(도)', ylabel='별점'>
