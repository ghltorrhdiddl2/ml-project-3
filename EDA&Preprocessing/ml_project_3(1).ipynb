# %%
import pandas as pd
import numpy as np

# %%
corp3url = 'https://raw.githubusercontent.com/ghltorrhdiddl2/ml-project-3/main/EDA%26Preprocessing/corp3.csv'
corp3 = pd.read_csv(corp3url)

# %%
corp3.drop(['Unnamed: 0'], axis=1, inplace=True)
corp3
# Out:
#               기업명 기업구분2                      기업구분  사원수2                 사원수  \
# 0         (주)페이타랩  중소기업  중소기업, 스타트업, 주식회사, 병역특례..    52    52 명  (2022년 기준)
# 1       (주)엠제이플렉스  중소기업  중소기업, 스타트업, 외부감사법인, 주식..   930   930 명  (2022년 기준)
# 2           (주)앰진  중소기업                중소기업, 주식회사     0                   0
# 3         (주)도킹블록  중소기업                중소기업, 주식회사    11    11 명  (2022년 기준)
# 4      (주)헥토이노베이션  중소기업  코스닥, 중소기업, 주식회사, 병역특례 ..   140   140 명  (2022년 기준)
# ..            ...   ...                       ...   ...                 ...
# 180        (주)유니텍    기타              외부감사법인, 주식회사    36    36 명  (2022년 기준)
# 181       (주)우리기술    기타       코스닥, 외부감사법인, 수출입 기업   115   115 명  (2022년 기준)
# 182      한국쓰리엠(주)    기타  외국 법인기업, 외부감사법인, 연구소, ..  1686  1686 명  (2022년 기준)
# 183      에스지에이(주)    기타     코스닥, 외국인 투자기업, 외부감사법인   193   193 명  (2022년 기준)
# 184  주식회사 한국미래에너지    기타                      주식회사    25    25 명  (2021년 기준)
#
# ...

# %%
corp3[corp3['사원수'] == '0'][0:25]
# Out:
#              기업명 기업구분2                       기업구분  사원수2 사원수  \
# 2          (주)앰진  중소기업                 중소기업, 주식회사     0   0
# 5     (주)세종분석연구원  중소기업                 중소기업, 주식회사     0   0
# 11        (주)이타즈  중소기업                       중소기업     0   0
# 12  (주)더블다운인터액티브  중소기업                 중소기업, 주식회사     0   0
# 14       (주)이지서티  중소기업         중소기업, 외부감사법인, 주식회사     0   0
# 17      네오뉴트라(주)  중소기업                       중소기업     0   0
# 18     (주)지앤티솔루션  중소기업  중소기업, 스타트업, 연구소, 주식회사, ..     0   0
# 19    에이디엠코리아(주)  중소기업   코스닥, 중소기업, 주식회사, 병역특례 ..     0   0
# 21    (주)에이치앤컨설팅  중소기업                       중소기업     0   0
# 22      (주)와이오엘오  중소기업                 중소기업, 스타트업     0   0
# 23       (주)세마그룹  중소기업                 중소기업, 주식회사     0   0
# 24       ㈜데이타메이션  중소기업                 중소기업, 주식회사     0   0
# 32  (주)엠에스링크앤솔루션  중소기업                 중소기업, 주식회사     0   0
# 34        (주)모비젠  중소기업   중소기업, 외부감사법인, 연구소, 주식회..     0   0
# 35    (주)에이아이스페라  중소기업      중소기업, 주식회사, 병역특례 인증업체     0   0
# ...

# %%
corp3.loc[2, '사원수'] = '20 명  (2022년 기준)'
corp3.loc[5, '사원수'] = '3 명  (2022년 기준)'
corp3.loc[11, '사원수'] = '17 명  (2022년 기준)'
corp3.loc[12, '사원수'] = '173 명  (2022년 기준)'
corp3.loc[14, '사원수'] = '82 명  (2022년 기준)'
corp3.loc[17, '사원수'] = '68 명  (2022년 기준)'
corp3.loc[18, '사원수'] = '42 명  (2022년 기준)'
corp3.loc[19, '사원수'] = '177 명  (2022년 기준)'
corp3.loc[21, '사원수'] = '20 명  (2022년 기준)'
corp3.loc[22, '사원수'] = '33 명  (2022년 기준)'
corp3.loc[23, '사원수'] = '30 명  (2022년 기준)'
corp3.loc[24, '사원수'] = '21 명  (2022년 기준)'
corp3.loc[32, '사원수'] = '36 명  (2022년 기준)'
corp3.loc[34, '사원수'] = '229 명  (2022년 기준)'
corp3.loc[35, '사원수'] = '44 명  (2022년 기준)'
corp3.loc[36, '사원수'] = '16 명  (2022년 기준)'
corp3.loc[38, '사원수'] = '28 명  (2022년 기준)'
corp3.loc[39, '사원수'] = '18 명  (2022년 기준)'
corp3.loc[40, '사원수'] = '235 명  (2022년 기준)'
corp3.loc[41, '사원수'] = '16 명  (2022년 기준)'
corp3.loc[45, '사원수'] = '63 명  (2022년 기준)'
corp3.loc[46, '사원수'] = '11 명  (2022년 기준)'
corp3.loc[48, '사원수'] = '26 명  (2022년 기준)'
corp3.loc[50, '사원수'] = '12 명  (2022년 기준)'
corp3.loc[51, '사원수'] = '134 명  (2022년 기준)'

# %%
corp3[corp3['사원수2'] == 0][0:25]
# Out:
#              기업명 기업구분2                       기업구분  사원수2                사원수  \
# 2          (주)앰진  중소기업                 중소기업, 주식회사     0   20 명  (2022년 기준)
# 5     (주)세종분석연구원  중소기업                 중소기업, 주식회사     0    3 명  (2022년 기준)
# 11        (주)이타즈  중소기업                       중소기업     0   17 명  (2022년 기준)
# 12  (주)더블다운인터액티브  중소기업                 중소기업, 주식회사     0  173 명  (2022년 기준)
# 14       (주)이지서티  중소기업         중소기업, 외부감사법인, 주식회사     0   82 명  (2022년 기준)
# 17      네오뉴트라(주)  중소기업                       중소기업     0   68 명  (2022년 기준)
# 18     (주)지앤티솔루션  중소기업  중소기업, 스타트업, 연구소, 주식회사, ..     0   42 명  (2022년 기준)
# 19    에이디엠코리아(주)  중소기업   코스닥, 중소기업, 주식회사, 병역특례 ..     0  177 명  (2022년 기준)
# 21    (주)에이치앤컨설팅  중소기업                       중소기업     0   20 명  (2022년 기준)
# 22      (주)와이오엘오  중소기업                 중소기업, 스타트업     0   33 명  (2022년 기준)
# 23       (주)세마그룹  중소기업                 중소기업, 주식회사     0   30 명  (2022년 기준)
# ...

# %%
df = df.replace(to_replace={'사원수2':{0:df['사원수'].str.split().str[0]}})

# %%
df
# Out:
#               기업명 기업구분2                      기업구분  사원수2                 사원수  \
# 0         (주)페이타랩  중소기업  중소기업, 스타트업, 주식회사, 병역특례..    52    52 명  (2022년 기준)
# 1       (주)엠제이플렉스  중소기업  중소기업, 스타트업, 외부감사법인, 주식..   930   930 명  (2022년 기준)
# 2           (주)앰진  중소기업                중소기업, 주식회사    20    20 명  (2022년 기준)
# 3         (주)도킹블록  중소기업                중소기업, 주식회사    11    11 명  (2022년 기준)
# 4      (주)헥토이노베이션  중소기업  코스닥, 중소기업, 주식회사, 병역특례 ..   140   140 명  (2022년 기준)
# ..            ...   ...                       ...   ...                 ...
# 180        (주)유니텍    기타              외부감사법인, 주식회사    36    36 명  (2022년 기준)
# 181       (주)우리기술    기타       코스닥, 외부감사법인, 수출입 기업   115   115 명  (2022년 기준)
# 182      한국쓰리엠(주)    기타  외국 법인기업, 외부감사법인, 연구소, ..  1686  1686 명  (2022년 기준)
# 183      에스지에이(주)    기타     코스닥, 외국인 투자기업, 외부감사법인   193   193 명  (2022년 기준)
# 184  주식회사 한국미래에너지    기타                      주식회사    25    25 명  (2021년 기준)
#
# ...

# %%
df['사원수2'] = df['사원수2'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   기업명      185 non-null    object
#  1   기업구분2    185 non-null    object
#  2   기업구분     185 non-null    object
#  3   사원수2     185 non-null    int32
#  4   사원수      185 non-null    object
#  5   설립일(업력)  185 non-null    object
#  6   홈페이지     173 non-null    object
#  7   지역       185 non-null    object
#  8   별점       185 non-null    float64
#  9   입사율      185 non-null    object
#  10  퇴사율      185 non-null    object
# dtypes: float64(1), int32(1), object(9)
# memory usage: 15.3+ KB

# %%
df.to_csv('company.csv')

# %%
df = pd.read_csv('company.csv')

# %%
df
# Out:
#      Unnamed: 0           기업명 기업구분2                      기업구분  사원수2  \
# 0             0       (주)페이타랩  중소기업  중소기업, 스타트업, 주식회사, 병역특례..    52
# 1             1     (주)엠제이플렉스  중소기업  중소기업, 스타트업, 외부감사법인, 주식..   930
# 2             2         (주)앰진  중소기업                중소기업, 주식회사    20
# 3             3       (주)도킹블록  중소기업                중소기업, 주식회사    11
# 4             4    (주)헥토이노베이션  중소기업  코스닥, 중소기업, 주식회사, 병역특례 ..   140
# ..          ...           ...   ...                       ...   ...
# 180         180        (주)유니텍    기타              외부감사법인, 주식회사    36
# 181         181       (주)우리기술    기타       코스닥, 외부감사법인, 수출입 기업   115
# 182         182      한국쓰리엠(주)    기타  외국 법인기업, 외부감사법인, 연구소, ..  1686
# 183         183      에스지에이(주)    기타     코스닥, 외국인 투자기업, 외부감사법인   193
# 184         184  주식회사 한국미래에너지    기타                      주식회사    25
#
#                     사원수                  설립일(업력)  \
# 0      52 명  (2022년 기준)    2018년 2월 28일 (업력 4년)
# 1     930 명  (2022년 기준)   2005년 3월 24일 (업력 17년)
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#           기업명 기업구분2                      기업구분  사원수2                사원수  \
# 0     (주)페이타랩  중소기업  중소기업, 스타트업, 주식회사, 병역특례..    52   52 명  (2022년 기준)
# 1   (주)엠제이플렉스  중소기업  중소기업, 스타트업, 외부감사법인, 주식..   930  930 명  (2022년 기준)
# 2       (주)앰진  중소기업                중소기업, 주식회사    20   20 명  (2022년 기준)
# 3     (주)도킹블록  중소기업                중소기업, 주식회사    11   11 명  (2022년 기준)
# 4  (주)헥토이노베이션  중소기업  코스닥, 중소기업, 주식회사, 병역특례 ..   140  140 명  (2022년 기준)
#
#                   설립일(업력)                                홈페이지       지역   별점  \
# 0   2018년 2월 28일 (업력 4년)                      passorder.co.kr  부산 부산진구  4.3
# 1  2005년 3월 24일 (업력 17년)                     www.mjplex.co.kr   서울 구로구  2.3
# 2  2012년 6월 13일 (업력 10년)                     www.amgine.co.kr   서울 송파구  3.0
# 3    2019년 3월 6일 (업력 3년)                     dockingblock.com   서울 강남구  0.0
# 4                       0  https://www.hectoinnovation.co.kr/   서울 강남구  3.3
#
#                입사율              퇴사율
# 0  114.71 % (39 명)   64.71 % (22 명)
# ...

# %%
df.loc[57, '설립일(업력)'] = '2013년 04월 15일 (업력 13년)'
df.loc[58, '설립일(업력)'] = '2008년 11월 3일 (업력 15년)'
df.loc[71, '설립일(업력)'] = '2010년 11월 (업력 12년)'
df.loc[73, '설립일(업력)'] = '2018년 4월 (업력 4년)'
df.loc[74, '설립일(업력)'] = '2007년 8월 10일 (업력 16년)'
df.loc[78, '설립일(업력)'] = '2016년 8월 (업력 6년)'
df.loc[79, '설립일(업력)'] = '2009년 10월 1일 (업력 14년)'
df.loc[81, '설립일(업력)'] = '2003년 1월 17일 (업력 20년)'
df.loc[83, '설립일(업력)'] = '2019년 1월 3일 (업력 4년)'
df.loc[84, '설립일(업력)'] = '2009년 10월 7 (업력 14년)'
df.loc[88, '설립일(업력)'] = '2019년 8월 23일 (업력 4년)'
df.loc[89, '설립일(업력)'] = '2019년 6월 4일 (업력 4년)'
df.loc[92, '설립일(업력)'] = '2003년 7월 1일 (업력 20년)'
df.loc[94, '설립일(업력)'] = '1998년 9월 28일 (업력 25년)'
df.loc[95, '설립일(업력)'] = '2019년 2월 1일 (업력 4년)'
df.loc[101, '설립일(업력)'] = '2003년 12월 1일 (업력 20년)'
df.loc[103, '설립일(업력)'] = '2018년 3월 2일 (업력 5년)'

# %%
df.loc[57, '사원수'] = '24 명  (2022년 기준)'
df.loc[58, '사원수'] = '33 명  (2022년 기준)'
df.loc[63, '사원수'] = '9 명  (2022년 기준)'
df.loc[64, '사원수'] = '71 명  (2022년 기준)'
df.loc[71, '사원수'] = '83 명  (2022년 기준)'
df.loc[72, '사원수'] = '7 명  (2022년 기준)'
df.loc[73, '사원수'] = '99 명  (2022년 기준)'
df.loc[74, '사원수'] = '14 명  (2022년 기준)'
df.loc[76, '사원수'] = '35 명  (2022년 기준)'
df.loc[78, '사원수'] = '14 명  (2022년 기준)'
df.loc[79, '사원수'] = '23 명  (2022년 기준)'
df.loc[81, '사원수'] = '163 명  (2022년 기준)'
df.loc[83, '사원수'] = '45 명  (2022년 기준)'
df.loc[84, '사원수'] = '19 명  (2022년 기준)'
df.loc[86, '사원수'] = '3 명  (2022년 기준)'
df.loc[87, '사원수'] = '224 명  (2022년 기준)'
df.loc[88, '사원수'] = '224 명  (2022년 기준)'
df.loc[89, '사원수'] = '95 명  (2022년 기준)'
df.loc[92, '사원수'] = '63 명  (2022년 기준)'
df.loc[94, '사원수'] = '80 명  (2022년 기준)'
df.loc[95, '사원수'] = '20 명  (2022년 기준)'
df.loc[99, '사원수'] = '20 명  (2022년 기준)'
df.loc[100, '사원수'] = '11 명  (2022년 기준)'
df.loc[101, '사원수'] = '61 명  (2022년 기준)'
df.loc[103, '사원수'] = '21 명  (2022년 기준)'
df.loc[106, '사원수'] = '15 명  (2022년 기준)'

# %%
df.at[184, '설립일(업력)'] = '2016년 12월 21일 (업력 6년)'
df.at[180, '설립일(업력)'] = '1989년 03월 30일 (업력 33년)'
df.at[179, '설립일(업력)'] = '1993년 09월 24일 (업력 29년)'
df.at[175,'설립일(업력)'] = '1999년 07월 01일 (업력 23년)'
df.at[173,'설립일(업력)'] = '2000년 07월 19일 (업력 22년)'
df.at[171,'설립일(업력)'] = '2000년 06월 01일 (업력 22년)'
df.at[169,'설립일(업력)'] = '1998년 04월 23일 (업력 24년)'
df.at[166,'설립일(업력)'] = '1985년 05월 10일 (업력 37년)'
df.at[163,'설립일(업력)'] = '2016년 07월 07일 (업력 6년)'
df.at[162,'설립일(업력)'] = '2009년 04월 01일 (업력 13년)'
df.at[161,'설립일(업력)'] = '1987년 01월 14일 (업력 35년)'
df.at[159,'설립일(업력)'] = '2001년 04월 02일 (업력 21년)'
df.at[153,'설립일(업력)'] = '2013년 03월 29일 (업력 9년)'
df.at[152,'설립일(업력)'] = '1998년 02월 23일 (업력 24년)'
df.at[151,'설립일(업력)'] = '2013년 02월 06일 (업력 9년)'
df.at[150,'설립일(업력)'] = '2000년 05월 29일 (업력 22년)'
df.at[145,'설립일(업력)'] = '1992년 09월 06일 (업력 30년)'
df.at[141,'설립일(업력)'] = '2018년 07월 03일 (업력 4년)'
df.at[140,'설립일(업력)'] = '1998년 04월 08일 (업력 24년)'
df.at[138,'설립일(업력)'] = '1994년 06월 28일 (업력 28년)'
df.at[137,'설립일(업력)'] = '2012년 04월 27일 (업력 10년)'
df.at[134,'설립일(업력)'] = '1994년 09월 15일 (업력 28년)'
df.at[129,'설립일(업력)'] = '2005년 07월 29일 (업력 17년)'
df.at[128,'설립일(업력)'] = '2001년 05월 11일 (업력 21년)'
df.at[126,'설립일(업력)'] = '2018년 02월 14일 (업력 4년)'
df.at[124,'설립일(업력)'] = '2003년 09월 05일 (업력 19년)'
df.at[123,'설립일(업력)'] = '2009년 12월 03일 (업력 13년)'
df.at[120,'설립일(업력)'] = '2016년 08월 26일 (업력 7년)'
df.at[119,'설립일(업력)'] = '2005년 03월 02일 (업력 18년)'
df.at[118,'설립일(업력)'] = '2016년 12월 16일 (업력 7년)'
df.at[115,'설립일(업력)'] = '2014년 09월 05일 (업력 8년)'
df.at[114,'설립일(업력)'] = '2016년 11월 18일 (업력 7년)'
df.at[107,'설립일(업력)'] = '2013년 11월 01일 (업력 9년)'
df.at[103,'설립일(업력)'] = '2018년 03월 07일 (업력 4년)'
df.at[101,'설립일(업력)'] = '2003년 12월 03일 (업력 19년)'

# %%
df.at[179, '사원수'] = '187 명  (2022년 기준)'
df.at[175,'사원수'] = '120 명  (2022년 기준)'
df.at[171,'사원수'] = '78 명  (2022년 기준)'
df.at[169,'사원수'] = '83 명  (2022년 기준)'
df.at[166,'사원수'] = '1169 명  (2022년 기준)'
df.at[162,'사원수'] = '65 명  (2022년 기준)'
df.at[159,'사원수'] = '1140 명  (2022년 기준)'
df.at[153,'사원수'] = '490 명  (2022년 기준)'
df.at[151,'사원수'] = '755 명  (2022년 기준)'
df.at[146,'사원수'] = '1431 명  (2022년 기준)'
df.at[137,'사원수'] = '321 명  (2022년 기준)'
df.at[134,'사원수'] = '45 명  (2022년 기준)'
df.at[129,'사원수'] = '60 명  (2022년 기준)'
df.at[128,'사원수'] = '60 명  (2022년 기준)'
df.at[127,'사원수'] = '3 명  (2022년 기준)'
df.at[126,'사원수'] = '45 명  (2022년 기준)'
df.at[123,'사원수'] = '26 명  (2022년 기준)'
df.at[120,'사원수'] = '50 명  (2022년 기준)'
df.at[118,'사원수'] = '52 명  (2022년 기준)'
df.at[115,'사원수'] = '32 명  (2022년 기준)'
df.at[114,'사원수'] = '2 명  (2022년 기준)'
df.at[111,'사원수'] = '60 명  (2022년 기준)'
df.at[107,'사원수'] =  '120 명  (2022년 기준)'
df.at[106,'사원수'] = '16 명  (2022년 기준)'

# %%
df.loc[57, '사원수'] = '24 명  (2022년 기준)'
df.loc[58, '사원수'] = '33 명  (2022년 기준)'
df.loc[63, '사원수'] = '9 명  (2022년 기준)'
df.loc[64, '사원수'] = '71 명  (2022년 기준)'
df.loc[71, '사원수'] = '83 명  (2022년 기준)'
df.loc[72, '사원수'] = '7 명  (2022년 기준)'
df.loc[73, '사원수'] = '99 명  (2022년 기준)'
df.loc[74, '사원수'] = '14 명  (2022년 기준)'
df.loc[76, '사원수'] = '35 명  (2022년 기준)'
df.loc[78, '사원수'] = '14 명  (2022년 기준)'
df.loc[79, '사원수'] = '23 명  (2022년 기준)'
df.loc[81, '사원수'] = '163 명  (2022년 기준)'
df.loc[83, '사원수'] = '45 명  (2022년 기준)'
df.loc[84, '사원수'] = '19 명  (2022년 기준)'
df.loc[86, '사원수'] = '3 명  (2022년 기준)'
df.loc[87, '사원수'] = '224 명  (2022년 기준)'
df.loc[88, '사원수'] = '224 명  (2022년 기준)'
df.loc[89, '사원수'] = '95 명  (2022년 기준)'
df.loc[92, '사원수'] = '63 명  (2022년 기준)'
df.loc[94, '사원수'] = '80 명  (2022년 기준)'
df.loc[95, '사원수'] = '20 명  (2022년 기준)'
df.loc[99, '사원수'] = '20 명  (2022년 기준)'
df.loc[100, '사원수'] = '11 명  (2022년 기준)'
df.loc[101, '사원수'] = '61 명  (2022년 기준)'
df.loc[103, '사원수'] = '21 명  (2022년 기준)'
df.loc[106, '사원수'] = '15 명  (2022년 기준)'

# %%
df.at[165,'홈페이지'] = 'https://www.naverz-corp.com/'
df.at[142,'홈페이지'] = 'http://www.megazone.com/'
df.at[122,'홈페이지'] = 'https://ivw-sw.notion.site/9d6d04ea74b64bd6a7f7251a0464b6e5'
df.at[106,'홈페이지'] = 'http://www.clrobur.com/en/'

# %%
df.at[89,'입사율'] = '32.10 % (26 명)'
df.at[89,'퇴사율'] = '129.63 % (105 명)'
df.at[140,'입사율'] = '27.21 % (209 명)'
df.at[140,'퇴사율'] = '119.40 % (917 명)'

# %%
df = df.replace(to_replace={'사원수2':{0:df['사원수'].str.split().str[0]}})

# %%
df.to_csv('company1.csv')

# %%
df1 = pd.read_csv('company1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   기업명      185 non-null    object
#  1   기업구분2    185 non-null    object
#  2   기업구분     185 non-null    object
#  3   사원수2     185 non-null    int64
#  4   사원수      185 non-null    object
#  5   설립일(업력)  185 non-null    object
#  6   홈페이지     173 non-null    object
#  7   지역       185 non-null    object
#  8   별점       185 non-null    float64
#  9   입사율      185 non-null    object
#  10  퇴사율      185 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 16.0+ KB

# %%
# 한글 설정
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == "Darwin":
    print("Hangul OK in your MAC!!!")
    rc("font", family="Arial Unicode MS")
elif platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    print("Hangul OK in your Windows!!!")
    rc("font", family=font_name)
else:
    print("Unknown system. sorry~~~")
    
plt.rcParams["axes.unicode_minus"] = False
# Out:
# Hangul OK in your Windows!!!

# %%
# 이상치 확인
plt.figure(figsize=(12, 8))
sns.boxplot(y=df['별점'])
plt.grid()
plt.show()

# %%
import plotly.express as px

fig = px.histogram(df, x='별점')
fig.show()
# 별점 2.3 ~ 2.7점 사이가 제일 많음

# %%
# 별점의 분포가 어떤지 : countplot 은 데이터의 개수를 표시하는 플롯
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='별점');

# %%
# 별점별 사원수 
plt.figure(figsize=(12, 8))
sns.barplot(x='별점', y='사원수2', data=df);

# %%
# 상관관계 확인
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, fmt = '.2f', lw=0.2, cmap = 'YlGnBu')
plt.show()
# plt.title('',fontsize= 20);

# %%
# 별점에 따른 기업 분포
df['별점'].value_counts().plot(kind='barh');
